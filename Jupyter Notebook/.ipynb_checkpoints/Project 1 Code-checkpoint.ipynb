# %%
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np
import scipy.stats as scipy
from scipy.stats import linregress
from scipy import stats

from sklearn.model_selection import train_test_split
from sklearn.linear_model import LinearRegression
from sklearn.preprocessing import PolynomialFeatures
from sklearn.metrics import r2_score

# %%
#Study Data Files
happiness_data_path = "Resources/2018.csv"
alcohol_data_path = "Resources/Alcohol_Data.csv"
happiness_2015 = "Resources/2015.csv"

#Read Happiness and Alcohol Data
happiness_data_df = pd.read_csv(happiness_data_path)
alcohol_data_df = pd.read_csv(alcohol_data_path, skiprows = 4)
happiness_2015_df = pd.read_csv(happiness_2015)

# %%
#Preview Dataframe
happiness_data_df
# Out:
#      Overall rank         Country or region  Score  GDP per capita  \
# 0               1                   Finland  7.632           1.305
# 1               2                    Norway  7.594           1.456
# 2               3                   Denmark  7.555           1.351
# 3               4                   Iceland  7.495           1.343
# 4               5               Switzerland  7.487           1.420
# ..            ...                       ...    ...             ...
# 151           152                     Yemen  3.355           0.442
# 152           153                  Tanzania  3.303           0.455
# 153           154               South Sudan  3.254           0.337
# 154           155  Central African Republic  3.083           0.024
# 155           156                   Burundi  2.905           0.091
#
#      Social support  Healthy life expectancy  Freedom to make life choices  \
# 0             1.592                    0.874                         0.681
# 1             1.582                    0.861                         0.686
# 2             1.590                    0.868                         0.683
# 3             1.644                    0.914                         0.677
# 4             1.549                    0.927                         0.660
# ..              ...                      ...                           ...
# 151           1.073                    0.343                         0.244
# 152           0.991                    0.381                         0.481
# 153           0.608                    0.177                         0.112
# 154           0.000                    0.010                         0.305
# 155           0.627                    0.145                         0.065
#
#      Generosity  Perceptions of corruption
# 0         0.202                      0.393
# 1         0.286                      0.340
# 2         0.284                      0.408
# 3         0.353                      0.138
# 4         0.256                      0.357
# ..          ...                        ...
# 151       0.083                      0.064
# 152       0.270                      0.097
# 153       0.224                      0.106
# 154       0.218                      0.038
# 155       0.149                      0.076
#
# [156 rows x 9 columns]

# %%
#Grab Columns Needed from CSV
alcohol_data_df = alcohol_data_df[["Country Name", "Country Code", "2018"]]
#Renamed Column to Allow Merge on "Country or region"
alcohol_data_df_renamed = alcohol_data_df.rename(columns = {"Country Name": "Country or region"})
alcohol_data_df_renamed
# Out:
#                Country or region Country Code      2018
# 0                          Aruba          ABW       NaN
# 1    Africa Eastern and Southern          AFE  5.170911
# 2                    Afghanistan          AFG  0.210000
# 3     Africa Western and Central          AFW  6.835266
# 4                         Angola          AGO  6.940000
# ..                           ...          ...       ...
# 261                       Kosovo          XKX       NaN
# 262                  Yemen, Rep.          YEM  0.051000
# 263                 South Africa          ZAF  9.520000
# 264                       Zambia          ZMB  6.540000
# 265                     Zimbabwe          ZWE  4.670000
#
# [266 rows x 3 columns]

# %%
#Grab Columns Needed From CSV
happiness_2015_df = happiness_2015_df[["Country", "Region"]]
#Renamed Column to Allow Merge on "Country or Region"
happiness_2015_df_renamed = happiness_2015_df.rename(columns = {"Country": "Country or region"})
happiness_2015_df_renamed
# Out:
#     Country or region                           Region
# 0         Switzerland                   Western Europe
# 1             Iceland                   Western Europe
# 2             Denmark                   Western Europe
# 3              Norway                   Western Europe
# 4              Canada                    North America
# ..                ...                              ...
# 153            Rwanda               Sub-Saharan Africa
# 154             Benin               Sub-Saharan Africa
# 155             Syria  Middle East and Northern Africa
# 156           Burundi               Sub-Saharan Africa
# 157              Togo               Sub-Saharan Africa
#
# [158 rows x 2 columns]

# %%
#Merge Alcohol Data and 2018 Data
happy_alcohol_df = pd.merge(alcohol_data_df_renamed, happiness_data_df, on=["Country or region"])
happy_alcohol_df
# Out:
#         Country or region Country Code  2018  Overall rank  Score  \
# 0             Afghanistan          AFG  0.21           145  3.632
# 1                  Angola          AGO  6.94           142  3.795
# 2                 Albania          ALB  7.17           112  4.586
# 3    United Arab Emirates          ARE  3.90            20  6.774
# 4               Argentina          ARG  9.65            29  6.388
# ..                    ...          ...   ...           ...    ...
# 132               Vietnam          VNM  8.66            95  5.103
# 133                Kosovo          XKX   NaN            66  5.662
# 134          South Africa          ZAF  9.52           105  4.724
# 135                Zambia          ZMB  6.54           125  4.377
# 136              Zimbabwe          ZWE  4.67           144  3.692
#
#      GDP per capita  Social support  Healthy life expectancy  \
# 0             0.332           0.537                    0.255
# 1             0.730           1.125                    0.269
# 2             0.916           0.817                    0.790
# 3             2.096           0.776                    0.670
# 4             1.073           1.468                    0.744
# ..              ...             ...                      ...
# 132           0.715           1.365                    0.702
# 133           0.855           1.230                    0.578
# 134           0.940           1.410                    0.330
# 135           0.562           1.047                    0.295
# 136           0.357           1.094                    0.248
#
#      Freedom to make life choices  Generosity  Perceptions of corruption
# 0                           0.085       0.191                      0.036
# 1                           0.000       0.079                      0.061
# 2                           0.419       0.149                      0.032
# 3                           0.284       0.186                        NaN
# 4                           0.570       0.062                      0.054
# ..                            ...         ...                        ...
# 132                         0.618       0.177                      0.079
# 133                         0.448       0.274                      0.023
# 134                         0.516       0.103                      0.056
# 135                         0.503       0.221                      0.082
# 136                         0.406       0.132                      0.099
#
# [137 rows x 11 columns]

# %%
#Merge New DataFrame with Pulled 2015 Data
happy_alcohol_df_final = pd.merge(happy_alcohol_df, happiness_2015_df_renamed, on=["Country or region"])
happy_alcohol_df_final
# Out:
#         Country or region Country Code  2018  Overall rank  Score  \
# 0             Afghanistan          AFG  0.21           145  3.632
# 1                  Angola          AGO  6.94           142  3.795
# 2                 Albania          ALB  7.17           112  4.586
# 3    United Arab Emirates          ARE  3.90            20  6.774
# 4               Argentina          ARG  9.65            29  6.388
# ..                    ...          ...   ...           ...    ...
# 128               Vietnam          VNM  8.66            95  5.103
# 129                Kosovo          XKX   NaN            66  5.662
# 130          South Africa          ZAF  9.52           105  4.724
# 131                Zambia          ZMB  6.54           125  4.377
# 132              Zimbabwe          ZWE  4.67           144  3.692
#
#      GDP per capita  Social support  Healthy life expectancy  \
# 0             0.332           0.537                    0.255
# 1             0.730           1.125                    0.269
# 2             0.916           0.817                    0.790
# 3             2.096           0.776                    0.670
# 4             1.073           1.468                    0.744
# ..              ...             ...                      ...
# 128           0.715           1.365                    0.702
# 129           0.855           1.230                    0.578
# 130           0.940           1.410                    0.330
# 131           0.562           1.047                    0.295
# 132           0.357           1.094                    0.248
#
#      Freedom to make life choices  Generosity  Perceptions of corruption  \
# 0                           0.085       0.191                      0.036
# 1                           0.000       0.079                      0.061
# 2                           0.419       0.149                      0.032
# 3                           0.284       0.186                        NaN
# 4                           0.570       0.062                      0.054
# ..                            ...         ...                        ...
# 128                         0.618       0.177                      0.079
# 129                         0.448       0.274                      0.023
# 130                         0.516       0.103                      0.056
# 131                         0.503       0.221                      0.082
# 132                         0.406       0.132                      0.099
#
#                               Region
# 0                      Southern Asia
# 1                 Sub-Saharan Africa
# 2         Central and Eastern Europe
# 3    Middle East and Northern Africa
# 4        Latin America and Caribbean
# ..                               ...
# 128                Southeastern Asia
# 129       Central and Eastern Europe
# 130               Sub-Saharan Africa
# 131               Sub-Saharan Africa
# 132               Sub-Saharan Africa
#
# [133 rows x 12 columns]

# %%
#Sort Final DataFrame, Reset Index, and Drop Rows with Any Null Values
happy_alcohol_df_sorted = happy_alcohol_df_final.sort_values(by=["Country or region"],ascending=True,ignore_index=True)
happy_alcohol_df_sorted_drop = happy_alcohol_df_sorted.dropna(how="any")
happy_alcohol_df_sorted_drop
# Out:
#     Country or region Country Code  2018  Overall rank  Score  GDP per capita  \
# 0         Afghanistan          AFG  0.21           145  3.632           0.332
# 1             Albania          ALB  7.17           112  4.586           0.916
# 2             Algeria          DZA  0.95            84  5.295           0.979
# 3              Angola          AGO  6.94           142  3.795           0.730
# 4           Argentina          ARG  9.65            29  6.388           1.073
# ..                ...          ...   ...           ...    ...             ...
# 128           Uruguay          URY  6.92            31  6.379           1.093
# 129        Uzbekistan          UZB  2.59            44  6.096           0.719
# 130           Vietnam          VNM  8.66            95  5.103           0.715
# 131            Zambia          ZMB  6.54           125  4.377           0.562
# 132          Zimbabwe          ZWE  4.67           144  3.692           0.357
#
#      Social support  Healthy life expectancy  Freedom to make life choices  \
# 0             0.537                    0.255                         0.085
# 1             0.817                    0.790                         0.419
# 2             1.154                    0.687                         0.077
# 3             1.125                    0.269                         0.000
# 4             1.468                    0.744                         0.570
# ..              ...                      ...                           ...
# 128           1.459                    0.771                         0.625
# 129           1.584                    0.605                         0.724
# 130           1.365                    0.702                         0.618
# 131           1.047                    0.295                         0.503
# 132           1.094                    0.248                         0.406
#
#      Generosity  Perceptions of corruption                           Region
# 0         0.191                      0.036                    Southern Asia
# 1         0.149                      0.032       Central and Eastern Europe
# 2         0.055                      0.135  Middle East and Northern Africa
# 3         0.079                      0.061               Sub-Saharan Africa
# 4         0.062                      0.054      Latin America and Caribbean
# ..          ...                        ...                              ...
# 128       0.130                      0.155      Latin America and Caribbean
# 129       0.328                      0.259       Central and Eastern Europe
# 130       0.177                      0.079                Southeastern Asia
# 131       0.221                      0.082               Sub-Saharan Africa
# 132       0.132                      0.099               Sub-Saharan Africa
#
# [131 rows x 12 columns]

# %%
#Create a Plot That Compares and Calculates the Correlation Between a Country's Alcohol Consumption and Happiness Score
x = happy_alcohol_df_sorted_drop["2018"]
y = happy_alcohol_df_sorted_drop["Score"]

plt.scatter(x, y, marker="o", facecolors="blue")

(slope, intercept, rvalue, pvalue, stderr) = linregress(x, y)
regress_values = x * slope + intercept
line_eq = "y = " + str(round(slope,2)) + "x + " + str(round(intercept,2))
plt.plot(x,regress_values,"r-")
plt.annotate(line_eq,(0,7.5),fontsize=15,color="red")

plt.xlabel("Alcohol Consumpution by Liters/Capita")
plt.ylabel("Happiness Score")
plt.title("Alcohol Consumption VS. Happiness Score (2018)")

correlation = scipy.pearsonr(x,y)
print(f"The correlation between alcohol consumption and a country's happiness score is {round(correlation[0],2)}")

plt.savefig("AlcoholVSHappiness.png")
# Out:
# The correlation between alcohol consumption and a country's happiness score is 0.38

# %%
x = happy_alcohol_df_sorted_drop["2018"]
y = happy_alcohol_df_sorted_drop["Overall rank"]

plt.scatter(x, y, marker="o", facecolors="blue")

(slope, intercept, rvalue, pvalue, stderr) = linregress(x, y)
regress_values = x * slope + intercept
line_eq = "y = " + str(round(slope,2)) + "x + " + str(round(intercept,2))
plt.plot(x,regress_values,"r-")
plt.annotate(line_eq,(0,7.5),fontsize=15,color="red")

plt.xlabel("Alcohol Consumpution by Liters/Capita")
plt.ylabel("Happiness Rank")
plt.title("Alcohol Consumption VS. Happiness Score (2018)")

correlation = scipy.pearsonr(x,y)
print(f"The correlation between alcohol consumption and a country's overall rank is {round(correlation[0],2)}")
# Out:
# The correlation between alcohol consumption and a country's overall rank is -0.38

# %%
happiness_rank_df_sorted = happy_alcohol_df_final.sort_values(by=["Overall rank"],ascending=True,ignore_index=True)
happiness_rank_df_sorted
# Out:
#             Country or region Country Code   2018  Overall rank  Score  \
# 0                     Finland          FIN  10.78             1  7.632
# 1                      Norway          NOR   7.41             2  7.594
# 2                     Denmark          DNK  10.26             3  7.555
# 3                     Iceland          ISL   9.12             4  7.495
# 4                 Switzerland          CHE  11.53             5  7.487
# ..                        ...          ...    ...           ...    ...
# 128                   Liberia          LBR   6.12           149  3.495
# 129                    Rwanda          RWA   8.95           151  3.408
# 130                  Tanzania          TZA  11.27           153  3.303
# 131  Central African Republic          CAF   2.38           155  3.083
# 132                   Burundi          BDI   7.19           156  2.905
#
#      GDP per capita  Social support  Healthy life expectancy  \
# 0             1.305           1.592                    0.874
# 1             1.456           1.582                    0.861
# 2             1.351           1.590                    0.868
# 3             1.343           1.644                    0.914
# 4             1.420           1.549                    0.927
# ..              ...             ...                      ...
# 128           0.076           0.858                    0.267
# 129           0.332           0.896                    0.400
# 130           0.455           0.991                    0.381
# 131           0.024           0.000                    0.010
# 132           0.091           0.627                    0.145
#
#      Freedom to make life choices  Generosity  Perceptions of corruption  \
# 0                           0.681       0.202                      0.393
# 1                           0.686       0.286                      0.340
# 2                           0.683       0.284                      0.408
# 3                           0.677       0.353                      0.138
# 4                           0.660       0.256                      0.357
# ..                            ...         ...                        ...
# 128                         0.419       0.206                      0.030
# 129                         0.636       0.200                      0.444
# 130                         0.481       0.270                      0.097
# 131                         0.305       0.218                      0.038
# 132                         0.065       0.149                      0.076
#
#                  Region
# 0        Western Europe
# 1        Western Europe
# 2        Western Europe
# 3        Western Europe
# 4        Western Europe
# ..                  ...
# 128  Sub-Saharan Africa
# 129  Sub-Saharan Africa
# 130  Sub-Saharan Africa
# 131  Sub-Saharan Africa
# 132  Sub-Saharan Africa
#
# [133 rows x 12 columns]

# %%
Bar = happiness_rank_df_sorted
Bar.plot('Country or region', '2018', figsize=(30,5), kind='bar')
# Out:
# <AxesSubplot:xlabel='Country or region'>

# %%
#Groupby Region
happy_alcohol_df_final_group = happy_alcohol_df_sorted_drop.groupby("Region")
happy_groupby_means = happy_alcohol_df_final_group.mean()
#Sort By Overall Mean of a Region
happy_groupby_means_sorted = happy_groupby_means.sort_values(by=["Score"],ascending=True)
happy_groupby_means_sorted
# Out:
#                                       2018  Overall rank     Score  \
# Region
# Sub-Saharan Africa                4.968364    128.060606  4.165273
# Southern Asia                     1.812714    111.714286  4.603857
# Southeastern Asia                 4.878750     78.375000  5.399750
# Eastern Asia                      7.733333     78.000000  5.428667
# Central and Eastern Europe        9.073333     76.208333  5.437250
# Middle East and Northern Africa   1.207846     67.923077  5.608615
# Latin America and Caribbean       5.692105     48.578947  5.997316
# Western Europe                   10.738000     23.000000  6.829100
# North America                     9.405000     12.500000  7.107000
# Australia and New Zealand        10.570000      9.000000  7.298000
#
#                                  GDP per capita  Social support  \
# Region
# Sub-Saharan Africa                     0.447515        0.955848
# Southern Asia                          0.625143        0.974429
# Southeastern Asia                      0.915750        1.285000
# Eastern Asia                           1.065667        1.373667
# Central and Eastern Europe             0.999417        1.314542
# Middle East and Northern Africa        1.133000        1.220154
# Latin America and Caribbean            0.884368        1.332368
# Western Europe                         1.325650        1.489750
# North America                          1.364000        1.501500
# Australia and New Zealand              1.304000        1.587000
#
#                                  Healthy life expectancy  \
# Region
# Sub-Saharan Africa                              0.269091
# Southern Asia                                   0.497286
# Southeastern Asia                               0.625875
# Eastern Asia                                    0.787333
# Central and Eastern Europe                      0.694833
# Middle East and Northern Africa                 0.683692
# Latin America and Caribbean                     0.666737
# Western Europe                                  0.895800
# North America                                   0.857500
# Australia and New Zealand                       0.893000
#
#                                  Freedom to make life choices  Generosity  \
# Region
# Sub-Saharan Africa                                   0.387485    0.176697
# Southern Asia                                        0.455714    0.243571
# Southeastern Asia                                    0.587375    0.321375
# Eastern Asia                                         0.515000    0.120333
# Central and Eastern Europe                           0.392250    0.122750
# Middle East and Northern Africa                      0.442077    0.150231
# Latin America and Caribbean                          0.516842    0.142158
# Western Europe                                       0.559550    0.223850
# North America                                        0.600000    0.306000
# Australia and New Zealand                            0.658000    0.363000
#
#                                  Perceptions of corruption
# Region
# Sub-Saharan Africa                                0.086576
# Southern Asia                                     0.097857
# Southeastern Asia                                 0.123750
# Eastern Asia                                      0.095000
# Central and Eastern Europe                        0.069042
# Middle East and Northern Africa                   0.130231
# Latin America and Caribbean                       0.080737
# Western Europe                                    0.214150
# North America                                     0.212000
# Australia and New Zealand                         0.345500

# %%
bar2 = happy_groupby_means_sorted
bar2["Region"] = happy_groupby_means_sorted.index
bar2.plot('Region', '2018', kind='bar', xlabel='Region (In Order of Increasing Happiness Ranking)', ylabel='Alcohol Consumption (Liters Per Capita)')
# Out:
# <AxesSubplot:xlabel='Region (In Order of Increasing Happiness Ranking)', ylabel='Alcohol Consumption (Liters Per Capita)'>

# %%
SS_Africa = happy_alcohol_df_sorted_drop.loc[happy_alcohol_df_sorted_drop["Region"] == "Sub-Saharan Africa"]
SS_Africa = SS_Africa["Score"]

Southern_Asia = happy_alcohol_df_sorted_drop.loc[happy_alcohol_df_sorted_drop["Region"] == "Southern Asia"]
Southern_Asia = Southern_Asia["Score"]

SE_Asia = happy_alcohol_df_sorted_drop.loc[happy_alcohol_df_sorted_drop["Region"] == "Southeastern Asia"]
SE_Asia = SE_Asia["Score"]

Eastern_Asia = happy_alcohol_df_sorted_drop.loc[happy_alcohol_df_sorted_drop["Region"] == "Eastern Asia"]
Eastern_Asia = Eastern_Asia["Score"]

CAE_Europe = happy_alcohol_df_sorted_drop.loc[happy_alcohol_df_sorted_drop["Region"] == "Central and Eastern Europe"]
CAE_Europe = CAE_Europe["Score"]

Middle_E_North_A = happy_alcohol_df_sorted_drop.loc[happy_alcohol_df_sorted_drop["Region"] == "Middle East and Northern Africa"]
Middle_E_North_A = Middle_E_North_A["Score"]

Latin_A_Caribbean = happy_alcohol_df_sorted_drop.loc[happy_alcohol_df_sorted_drop["Region"] == "Latin America and Caribbean"]
Latin_A_Caribbean = Latin_A_Caribbean["Score"]

Western_Europe = happy_alcohol_df_sorted_drop.loc[happy_alcohol_df_sorted_drop["Region"] == "Western Europe"]
Western_Europe = Western_Europe["Score"]

North_Am = happy_alcohol_df_sorted_drop.loc[happy_alcohol_df_sorted_drop["Region"] == "North America"]
North_Am = North_Am["Score"]

Aust = happy_alcohol_df_sorted_drop.loc[happy_alcohol_df_sorted_drop["Region"] == "Australia and New Zealand"]
Aust = Aust["Score"]

# %%
scipy.kruskal(SS_Africa, Southern_Asia, SE_Asia, Eastern_Asia, CAE_Europe, Middle_E_North_A, Latin_A_Caribbean, 
               Western_Europe, North_Am, Aust)
# Out:
# KruskalResult(statistic=88.14525980898794, pvalue=3.8327116594272274e-15)

# %%
#Calculate the Quartiles for Drinking

#Create empty list to fill with Drinking information (for plotting)
quartiles = []
means=[]
uppers = []
lowers=[]

q3, q1 = np.percentile(happy_alcohol_df_sorted_drop["2018"], [75 ,25])
iqr = q3 - q1
quartiles.append(iqr)
mean=happy_alcohol_df_sorted_drop["2018"].mean()
upper=q3+(iqr*1.5)
lower=q1-(iqr*1.5)

upper_outliers=happy_alcohol_df_sorted_drop.loc[happy_alcohol_df_sorted_drop["2018"] > upper]
lower_outliers=happy_alcohol_df_sorted_drop.loc[happy_alcohol_df_sorted_drop["2018"] < lower]

# %%
print(q3, q1, iqr)
# Out:
# 9.629999999999999 2.525 7.104999999999999

# %%
#Create a Plot That Compares and Calculates the Correlation Between a Country's Alcohol Consumption and GDP
y = happy_alcohol_df_sorted_drop["2018"]
x = happy_alcohol_df_sorted_drop["GDP per capita"]

plt.scatter(x, y, marker="o", facecolors="blue")

(slope, intercept, rvalue, pvalue, stderr) = linregress(x, y)
regress_values = x * slope + intercept
line_eq = "y = " + str(round(slope,2)) + "x + " + str(round(intercept,2))
plt.plot(x,regress_values,"r-")
plt.annotate(line_eq,(0,7.5),fontsize=15,color="red")

plt.xlabel("GDP per Capita")
plt.ylabel("Drinking")
plt.title("Alcohol Consumption VS. GDP(2018)")

correlation = scipy.pearsonr(x,y)
print(f"The correlation between alcohol consumption and GDP per capita is {round(correlation[0],2)}")

plt.savefig("AlcoholVSGDP.png")
# Out:
# The correlation between alcohol consumption and GDP per capita is 0.42

# %%
'''#Attempting to Calculate and Create a Polynomial Linear Regression
happy_alcohol_df_sorted_drop_renamed = happy_alcohol_df_sorted_drop.rename(columns= {"2018": "AverageDrinks",
                                                                          "GDP per capita": "GDP_per_capita"})
happy_alcohol_df_sorted_drop_renamed

#Grab Information We are Trying to Test
AverageDrinks = []
AverageDrink = happy_alcohol_df_sorted_drop_renamed["AverageDrinks"]

for item in AverageDrink:
    AverageDrinks.append(item)
    
print(AverageDrinks)

GDP = []
GDP_per_capita = happy_alcohol_df_sorted_drop_renamed["GDP_per_capita"]


for item in GDP_per_capita:
    GDP.append(item)
    
print(GDP)

x = GDP
y = AverageDrinks

#Split Data in Train and Test Set (test size = what percent of test data should be dataset (0.2=20%)
x_train, x_test, y_train, y_test = train_test_split(x, y, test_size=0.2, random_state=2)

print(x_train)

#applying polynomial regression (using the degree as 2 since the OG equation calculated the intercept to be 2.23, it'll
#close enough for this test)
poly = PolynomialFeatures(degree=2, include_bias=True)
x_train_trans = poly.fit_transform(x_train)

#print(x_train_trans)

#x_test_trans = poly.transform(x_test)


#include bias parameter
#lr = LinearRegression()
#lr.fit(x_train, y_train)
#y_pred = lr.predict(x_test)
#print(r2_score(y_test, y_pred))'''
# Out:
# '#Attempting to Calculate and Create a Polynomial Linear Regression\nhappy_alcohol_df_sorted_drop_renamed = happy_alcohol_df_sorted_drop.rename(columns= {"2018": "AverageDrinks",\n                                                                          "GDP per capita": "GDP_per_capita"})\nhappy_alcohol_df_sorted_drop_renamed\n\n#Grab Information We are Trying to Test\nAverageDrinks = []\nAverageDrink = happy_alcohol_df_sorted_drop_renamed["AverageDrinks"]\n\nfor item in AverageDrink:\n    AverageDrinks.append(item)\n    \nprint(AverageDrinks)\n\nGDP = []\nGDP_per_capita = happy_alcohol_df_sorted_drop_renamed["GDP_per_capita"]\n\n\nfor item in GDP_per_capita:\n    GDP.append(item)\n    \nprint(GDP)\n\nx = GDP\ny = AverageDrinks\n\n#Split Data in Train and Test Set (test size = what percent of test data should be dataset (0.2=20%)\nx_train, x_test, y_train, y_test = train_test_split(x, y, test_size=0.2, random_state=2)\n\nprint(x_train)\n\n#applying polynomial regression (using the degree as 2 since the OG equation calculated the intercept to be 2.23, it\'ll\n#close enough for this test)\npoly = PolynomialFeatures(degree=2, include_bias=True)\nx_train_trans = poly.fit_transform(x_train)\n\n#print(x_train_trans)\n\n#x_test_trans = poly.transform(x_test)\n\n\n#include bias parameter\n#lr = LinearRegression()\n#lr.fit(x_train, y_train)\n#y_pred = lr.predict(x_test)\n#print(r2_score(y_test, y_pred))'

# %%
#Repeat with Social Support
y = happy_alcohol_df_sorted_drop["2018"]
x = happy_alcohol_df_sorted_drop["Social support"]

plt.scatter(x, y, marker="o", facecolors="blue")

(slope, intercept, rvalue, pvalue, stderr) = linregress(x, y)
regress_values = x * slope + intercept
line_eq = "y = " + str(round(slope,2)) + "x + " + str(round(intercept,2))
plt.plot(x,regress_values,"r-")
plt.annotate(line_eq,(0,7.5),fontsize=15,color="red")

plt.xlabel("Social Support")
plt.ylabel("Drinking")
plt.title("Alcohol Consumption VS. Social Support (2018)")

correlation = scipy.pearsonr(x,y)
print(f"The correlation between alcohol consumption and social support is {round(correlation[0],2)}")

plt.savefig("AlcoholVSSocialSupport.png")
# Out:
# The correlation between alcohol consumption and social support is 0.45

# %%
#Repeat with Freedom to Make Life Choices
y = happy_alcohol_df_sorted_drop["2018"]
x = happy_alcohol_df_sorted_drop["Freedom to make life choices"]

plt.scatter(x, y, marker="o", facecolors="blue")

(slope, intercept, rvalue, pvalue, stderr) = linregress(x, y)
regress_values = x * slope + intercept
line_eq = "y = " + str(round(slope,2)) + "x + " + str(round(intercept,2))
plt.plot(x,regress_values,"r-")
plt.annotate(line_eq,(0,7.5),fontsize=15,color="red")

plt.xlabel("Life Choice Freedoms")
plt.ylabel("Drinking")
plt.title("Alcohol Consumption VS. Life Choice (2018)")

correlation = scipy.pearsonr(x,y)
print(f"The correlation between alcohol consumption and a country's freedom to make life choices is {round(correlation[0],2)}")

plt.savefig("AlcoholVSFreedom.png")
# Out:
# The correlation between alcohol consumption and a country's freedom to make life choices is 0.2

# %%
#Repeat with Generosity
y = happy_alcohol_df_sorted_drop["2018"]
x = happy_alcohol_df_sorted_drop["Generosity"]

plt.scatter(x, y, marker="o", facecolors="blue")

(slope, intercept, rvalue, pvalue, stderr) = linregress(x, y)
regress_values = x * slope + intercept
line_eq = "y = " + str(round(slope,2)) + "x + " + str(round(intercept,2))
plt.plot(x,regress_values,"r-")
plt.annotate(line_eq,(0,7.5),fontsize=15,color="red")

plt.xlabel("Generosity")
plt.ylabel("Drinking")
plt.title("Alcohol Consumption VS. Generosity (2018)")

correlation = scipy.pearsonr(x,y)
print(f"The correlation between alcohol consumption and a country's generosity is {round(correlation[0],2)}")

plt.savefig("AlcoholVSGenerosity.png")
# Out:
# The correlation between alcohol consumption and a country's generosity is -0.07

# %%
#Repeat with Government Corruption
y = happy_alcohol_df_sorted_drop["2018"]
x = happy_alcohol_df_sorted_drop["Perceptions of corruption"]

plt.scatter(x, y, marker="o", facecolors="blue")

(slope, intercept, rvalue, pvalue, stderr) = linregress(x, y)
regress_values = x * slope + intercept
line_eq = "y = " + str(round(slope,2)) + "x + " + str(round(intercept,2))
plt.plot(x,regress_values,"r-")
plt.annotate(line_eq,(0,7.5),fontsize=15,color="red")

plt.xlabel("Corruptions")
plt.ylabel("Drinking")
plt.title("Alcohol Consumption VS. Corruption (2018)")

correlation = scipy.pearsonr(x,y)
print(f"The correlation between alcohol consumption and a country's assumed level of government corruption is {round(correlation[0],2)}")

plt.savefig("AlcoholVSCorruption.png")
# Out:
# The correlation between alcohol consumption and a country's assumed level of government corruption is 0.13

# %%
#Repeat with Life Expectancy
y = happy_alcohol_df_sorted_drop["2018"]
x = happy_alcohol_df_sorted_drop["Healthy life expectancy"]

plt.scatter(x, y, marker="o", facecolors="blue")

(slope, intercept, rvalue, pvalue, stderr) = linregress(x, y)
regress_values = x * slope + intercept
line_eq = "y = " + str(round(slope,2)) + "x + " + str(round(intercept,2))
plt.plot(x,regress_values,"r-")
plt.annotate(line_eq,(0,7.5),fontsize=15,color="red")

plt.xlabel("Healthy Life Expectancy")
plt.ylabel("Drinking")
plt.title("Alcohol Consumption VS. Life Expectancy (2018)")

correlation = scipy.pearsonr(x,y)
print(f"The correlation between alcohol consumption and a country's life expectancy is {round(correlation[0],2)}")

plt.savefig("AlcoholVSLifeExpectancy.png")
# Out:
# The correlation between alcohol consumption and a country's life expectancy is 0.43

# %%
#HADFSD = pd.DataFrame(happy_alcohol_df_sorted_drop)
#HADFSD_renamed = HADFSD.rename(columns={"Overall Rank": "Overall_Rank"})
#HADFSD_renamed
#Kruskall_Attempt = HADFSD_renamed.groupby('Region').apply(lambda x: pd.Series(dict(Overall_Rank_Sum = x.Overall_Rank.sum())))
#Kruskall_Attempt

happy_alcohol_df_final_group = happy_alcohol_df_sorted_drop.groupby("Region")
happy_groupby_sums = happy_alcohol_df_final_group.sum()
happy_groupby_sums['Country_Count'] = happy_alcohol_df_sorted_drop.loc[happy_alcohol_df_sorted_drop["Region"]]
happy_groupby_sums
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_24484/533549991.py in <module>
#       7 happy_alcohol_df_final_group = happy_alcohol_df_sorted_drop.groupby("Region")
#       8 happy_groupby_sums = happy_alcohol_df_final_group.sum()
# ----> 9 happy_groupby_sums['Country_Count'] = happy_alcohol_df_sorted_drop.loc[happy_alcohol_df_sorted_drop["Region"]]
#      10 happy_groupby_sums
#
# ~\anaconda3\lib\site-packages\pandas\core\indexing.py in __getitem__(self, key)
#     929
#     930             maybe_callable = com.apply_if_callable(key, self.obj)
# --> 931             return self._getitem_axis(maybe_callable, axis=axis)
#     932
#     933     def _is_scalar_access(self, key: tuple):
#
# ~\anaconda3\lib\site-packages\pandas\core\indexing.py in _getitem_axis(self, key, axis)
#    1151                     raise ValueError("Cannot index with multidimensional key")
#    1152
# -> 1153                 return self._getitem_iterable(key, axis=axis)
#    1154
#    1155             # nested tuple slicing
#
# ~\anaconda3\lib\site-packages\pandas\core\indexing.py in _getitem_iterable(self, key, axis)
#    1091
#    1092         # A collection of keys
# -> 1093         keyarr, indexer = self._get_listlike_indexer(key, axis)
#    1094         return self.obj._reindex_with_indexers(
#    1095             {axis: [keyarr, indexer]}, copy=True, allow_dups=True
#
# ~\anaconda3\lib\site-packages\pandas\core\indexing.py in _get_listlike_indexer(self, key, axis)
#    1312             keyarr, indexer, new_indexer = ax._reindex_non_unique(keyarr)
#    1313
# -> 1314         self._validate_read_indexer(keyarr, indexer, axis)
#    1315
#    1316         if needs_i8_conversion(ax.dtype) or isinstance(
#
# ~\anaconda3\lib\site-packages\pandas\core\indexing.py in _validate_read_indexer(self, key, indexer, axis)
#    1372                 if use_interval_msg:
#    1373                     key = list(key)
# -> 1374                 raise KeyError(f"None of [{key}] are in the [{axis_name}]")
#    1375
#    1376             not_found = list(ensure_index(key)[missing_mask.nonzero()[0]].unique())
#
# KeyError: "None of [Index(['Southern Asia', 'Central and Eastern Europe',\n       'Middle East and Northern Africa', 'Sub-Saharan Africa',\n       'Latin America and Caribbean', 'Central and Eastern Europe',\n       'Australia and New Zealand', 'Western Europe',\n       'Central and Eastern Europe', 'Middle East and Northern Africa',\n       ...\n       'Central and Eastern Europe', 'Sub-Saharan Africa',\n       'Central and Eastern Europe', 'Western Europe', 'North America',\n       'Latin America and Caribbean', 'Central and Eastern Europe',\n       'Southeastern Asia', 'Sub-Saharan Africa', 'Sub-Saharan Africa'],\n      dtype='object', length=131)] are in the [index]"
